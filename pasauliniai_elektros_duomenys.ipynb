# %% [markdown]
# <a href="https://colab.research.google.com/github/tauriux/duomenynas/blob/main/pasauliniai_elektros_duomenys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
#df = pd.read_csv('kazkoks failas')

# %%
# importuojam duomenis
elektra = pd.read_csv('Global Electricity Statistics.csv')
elektra



#elektra.groupby(features)


#pd.group_by[]
#df[Yearscombined] = [df(Sum['1980'] : [2021])],
#for bendras_suvartojimas in range(1991, 2021):
    #print(sum(columns))
# Out:
#                                Country              Features  \
# 0                              Algeria        net generation
# 1                               Angola        net generation
# 2                                Benin        net generation
# 3                             Botswana        net generation
# 4                         Burkina Faso        net generation
# ...                                ...                   ...
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983     1984  \
# 0                      Africa    6.683     7.65    8.824    9.615   10.537
# 1                      Africa    0.905    0.906    0.995    1.028    1.028
# ...

# %%
elektra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   1610 non-null   object
#  1   Features  1610 non-null   object
#  2   Region    1610 non-null   object
#  3   1980      1582 non-null   object
#  4   1981      1582 non-null   object
#  5   1982      1582 non-null   object
#  6   1983      1582 non-null   object
#  7   1984      1582 non-null   object
#  8   1985      1582 non-null   object
#  9   1986      1582 non-null   object
#  10  1987      1582 non-null   object
#  11  1988      1582 non-null   object
#  12  1989      1582 non-null   object
#  13  1990      1582 non-null   object
#  14  1991      1582 non-null   object
#  15  1992      1582 non-null   object
#  16  1993      1582 non-null   object
#  17  1994      1582 non-null   object
#  18  1995      1582 non-null   object
#  19  1996      1582 non-null   object
# ...

# %%
# elektra['1980'].astype(Float)
visi_metai = [ str(metai) for metai in list(range(1980, 2022))]
# visi_metai
# elektra[["1980", "1981"]] = elektra[["1980", "1981"]].apply(pd.to_numeric, errors='coerce')
elektra[visi_metai] = elektra[visi_metai].apply(pd.to_numeric, errors='coerce')
elektra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   1610 non-null   object
#  1   Features  1610 non-null   object
#  2   Region    1610 non-null   object
#  3   1980      1358 non-null   float64
#  4   1981      1358 non-null   float64
#  5   1982      1358 non-null   float64
#  6   1983      1358 non-null   float64
#  7   1984      1358 non-null   float64
#  8   1985      1358 non-null   float64
#  9   1986      1365 non-null   float64
#  10  1987      1358 non-null   float64
#  11  1988      1358 non-null   float64
#  12  1989      1358 non-null   float64
#  13  1990      1365 non-null   float64
#  14  1991      1358 non-null   float64
#  15  1992      1484 non-null   float64
#  16  1993      1491 non-null   float64
#  17  1994      1498 non-null   float64
#  18  1995      1498 non-null   float64
# ...

# %%
# stulpeliai = list(elektra.columns)[14:] # nuo 14 stulpelio
# stulpeliai

# %%
elektra['1991_2021'] = elektra.iloc[:, 14:45].sum(axis=1)

# print("---Updated Dataframe---\n", elektra)
elektra
# Out:
#                                Country              Features  \
# 0                              Algeria        net generation
# 1                               Angola        net generation
# 2                                Benin        net generation
# 3                             Botswana        net generation
# 4                         Burkina Faso        net generation
# ...                                ...                   ...
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983      1984  \
# 0                      Africa  6.68300  7.65000  8.82400  9.61500  10.53700
# 1                      Africa  0.90500  0.90600  0.99500  1.02800   1.02800
# ...

# %%
# distinct_count = elektra['Features'].nunique()

# %%
elektra.info()

# %% [markdown]
# # Regionai.

# %%
elektra.groupby('Region').mean()['1991_2021']# grupuojant labai kad vienas komponentas butu skaiciavimui
# Out:
# <ipython-input-96-4b5e110d7734>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   elektra.groupby('Region').mean()['1991_2021']# grupuojant labai kad vienas komponentas butu skaiciavimui
# Region
# Africa                      102.716148
# Asia & Oceania             1385.806494
# Central & South America     222.170386
# Eurasia                    1066.644161
# Europe                      825.264514
# Middle East                 508.938340
# North America              6697.099769
# Name: 1991_2021, dtype: float64

# %%
# Kopel nespausdina tik Eropos?
elektra.loc[elektra['Region'] == 'Europe']
# Out:
#                              Country              Features  Region    1980  \
# 70                           Albania        net generation  Europe   3.635
# 71                           Austria        net generation  Europe  40.574
# 72                           Belgium        net generation  Europe  50.572
# 73            Bosnia and Herzegovina        net generation  Europe     NaN
# 74                          Bulgaria        net generation  Europe  32.854
# ...                              ...                   ...     ...     ...
# 1490                           Spain  distribution losses   Europe   9.966
# 1491                          Sweden  distribution losses   Europe   8.279
# 1492                     Switzerland  distribution losses   Europe   3.198
# 1493                         Turkiye  distribution losses   Europe   2.824
# 1494                  United Kingdom  distribution losses   Europe  21.534
#
# ...

# %%
elektra.groupby(['Region', 'Features']).mean()['1991_2021']# sitas sup
# Out:
# <ipython-input-99-8006c9022ac9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   elektra.groupby(['Region', 'Features']).mean()['1991_2021']# sitas sup
# Region                   Features
# Africa                   distribution losses        40.346380
#                          exports                    13.311646
#                          imports                    14.783091
#                          installed capacity         75.966018
#                          net consumption           267.129760
#                          net generation            306.004696
#                          net imports                 1.471445
# Asia & Oceania           distribution losses       335.542124
#                          exports                    19.810000
# ...

# %%
# elektra['Region']
# elektra['1991_2021']
# #s

# %%
#max
elektra.groupby('Region').mean()['1991_2021']
# Out:
# <ipython-input-103-f73c7a2f10f3>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   elektra.groupby('Region').mean()['1991_2021']
# Region
# Africa                      102.716148
# Asia & Oceania             1385.806494
# Central & South America     222.170386
# Eurasia                    1066.644161
# Europe                      825.264514
# Middle East                 508.938340
# North America              6697.099769
# Name: 1991_2021, dtype: float64

# %%
#elektra.iloc[elektra['Region'] == Europe] # neveikia
#naujas bandymas
# print('Global Electricity Statistics.csv')
# print(elektra)

euro_eilutes = elektra.loc[elektra['Region'] == 'Europe']
# print("\n")
euro_eilutes
# Out:
#                              Country              Features  Region    1980  \
# 70                           Albania        net generation  Europe   3.635
# 71                           Austria        net generation  Europe  40.574
# 72                           Belgium        net generation  Europe  50.572
# 73            Bosnia and Herzegovina        net generation  Europe     NaN
# 74                          Bulgaria        net generation  Europe  32.854
# ...                              ...                   ...     ...     ...
# 1490                           Spain  distribution losses   Europe   9.966
# 1491                          Sweden  distribution losses   Europe   8.279
# 1492                     Switzerland  distribution losses   Europe   3.198
# 1493                         Turkiye  distribution losses   Europe   2.824
# 1494                  United Kingdom  distribution losses   Europe  21.534
#
# ...

# %%
plt.bar(elektra['Region'], elektra['1991_2021'])
plt.ylim(2950, 120000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(elektra['Features'], elektra['1991_2021'])
#plt.annotate(txt, (x[i], y[i]), rotation=45)
plt.legend('Features')
plt.xlabel(rotation=90)

plt.show()

# prideti dizainu, laba

#grafikas tarp energetiniu

#plt.bar(elektra['Features'], elektra['1991_2021'])

#plt.show()

# %%
# legend liniju pavadinimai



elektra[elektra['Region'] == 'Europe'] [14:45]

x = [1, 10, 20, 30, 40, 50,]
y = [10, 50, 100, 150, 200]

# duodam linijai pavadinimą
plt.plot(x, y, label='Europe')

plt.title('Grafikas')

plt.xlabel('Nariai')
plt.ylabel('Apimtis')

# iškviečiam legendą
plt.legend()
plt.annotate(txt, (x[i], y[i]), rotation=45)
plt.show()

# %%
elektra.loc[elektra['Region'] == 'Europe'][14:45]

# %%
elektra[elektra['Features'] == 'installed capacity']

# %%
labels = ['generating', '', 'Category C', 'Category D']
sizes = [15, 30, 45, 10]
#  distribution losses       174.840990
#  exports                   234.118077
#  imports                   240.200908
#  installed capacity        652.684231
#  net consumption          2150.083199
#  net generation           2318.841358
#  net imports

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Elektros aspektai')

# Display the chart
plt.show()

# %%
# elektra.loc[elektra['Features'] == 'installed capacity'].groupby(['Region']).mean()['1991_2021']
# elektra.loc[elektra['Features'] == 'installed capacity']
# elektra.loc[elektra['Features'] == 'net generation']
installed_capacity_by_regions = elektra.loc[elektra['Features'].str.strip() == 'installed_capacity'].groupby('Region').sum()['1991_2021']
installed_capacity_by_regions
# Out:
# <ipython-input-140-fae155119086>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   installed_capacity_by_regions = elektra.loc[elektra['Features'].str.strip() == 'installed_capacity'].groupby('Region').sum()['1991_2021']
# Series([], Name: 1991_2021, dtype: float64)

# %%
installed_capacity_by_regions.plot(kind='bar')
# label turimi
# Out:
# <Axes: xlabel='Region'>

# %%
#cia kopija
